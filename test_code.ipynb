# %%
import matplotlib.pyplot as plt
from visualization.decision_boundary import plot_decision_boundary
from activation.activation_functions import softmax
from perceptron.MLP import ANN
from sklearn.datasets import make_circles

# %%
X,y = make_circles(n_samples=500,noise = 0.2,factor=0.2,shuffle=True,random_state=2)

SPLIT_SIZE = 0.9
SPLIT_NO = int(X.shape[0]*SPLIT_SIZE)

x_train = X[:SPLIT_NO]
y_train = y[:SPLIT_NO]
x_test = X[SPLIT_NO:]
y_test = y[SPLIT_NO:]

# %%
x_train.shape
# Out:
# (450, 2)

# %%
y_test.shape
# Out:
# (50,)

# %%
# create model
model = ANN(hidden_layers=[32,32,16,8],output_layer=2,input_layer=2)

# %%
# fit the model
hist = model.fit(x_train,y_train,batch_size=32,epochs=25,metrics = "accuracy")
# Out:
# EPOCH-->1
#  Training Loss----->   0.4428772747757786
# EPOCH-->2
#  Training Loss----->   0.4364429666632277
# EPOCH-->3
#  Training Loss----->   0.1941392108104528
# EPOCH-->4
#  Training Loss----->   0.13554401996924179
# EPOCH-->5
#  Training Loss----->   0.14373330187738814
# EPOCH-->6
#  Training Loss----->   0.12298261590427673
# EPOCH-->7
#  Training Loss----->   0.11922977177558261
# EPOCH-->8
#  Training Loss----->   0.09955448682615364
# EPOCH-->9
#  Training Loss----->   0.06273816518358741
# EPOCH-->10
#  Training Loss----->   0.07972052265831533
# EPOCH-->11
#  Training Loss----->   0.11551798377163182
# EPOCH-->12
#  Training Loss----->   0.1113653386536305
# EPOCH-->13
#  Training Loss----->   0.06571441400745767
# EPOCH-->14
#  Training Loss----->   0.05708874318351966
# EPOCH-->15
#  Training Loss----->   0.036355950582354496
# EPOCH-->16
#  Training Loss----->   0.09623089038105909
# EPOCH-->17
#  Training Loss----->   0.07737861896077179
# EPOCH-->18
#  Training Loss----->   0.0799463652811602
# EPOCH-->19
#  Training Loss----->   0.07966662702560284
# EPOCH-->20
#  Training Loss----->   0.0725216338969318
# EPOCH-->21
#  Training Loss----->   0.05833722086011638
# EPOCH-->22
#  Training Loss----->   0.07501860470003248
# EPOCH-->23
#  Training Loss----->   0.05602046748134491
# EPOCH-->24
#  Training Loss----->   0.08312646033701379
# EPOCH-->25
#  Training Loss----->   0.1350325940758184

# %%
# prediction of model
# pred is a dictionary which contains output and probability of resulted output
pred = model.predict(x_test[23])

# %%
print(y_test[23])

print(pred["output"])
# Out:
# 1
# [1]

# %%
# calculate accuracy of training set
print(model.cal_accuracy(x_train,y_train,"accuracy"))

# calculate accuracy of testing set
print(model.cal_accuracy(x_test,y_test,"accuracy"))
# Out:
# 0.9733333333333334
# 0.9

# %%
hist[1]
# Out:
# 97.33333333333334

# %%
# plot decision boundary
plot_decision_boundary(lambda x : model.predict(x)["output"],X,y)

# %%
plt.plot(hist[0]["loss_per_epoch"])
